# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
#to import dataset 
import plotly.express as px

# %%
#-----------------Relational plot

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# x = total and y = tips
#-----and plot a graph scatter

# %%
#axis level 
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='sex',style='time',size='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#figure level 
sns.relplot(data=tips,x='total_bill',y='tip',kind='scatter',hue='sex',style='time',size='size')

# %%
#_____________line plot

# %%
gap = px.data.gapminder()

# %%
df= gap[gap['country']=='Pakistan']
df.head()
# Out:
#        country continent  year  lifeExp       pop    gdpPercap iso_alpha  \
# 1164  Pakistan      Asia  1952   43.436  41346560   684.597144       PAK
# 1165  Pakistan      Asia  1957   45.557  46679944   747.083529       PAK
# 1166  Pakistan      Asia  1962   47.670  53100671   803.342742       PAK
# 1167  Pakistan      Asia  1967   49.800  60641899   942.408259       PAK
# 1168  Pakistan      Asia  1972   51.929  69325921  1049.938981       PAK
#
#       iso_num
# 1164      586
# 1165      586
# 1166      586
# 1167      586
# 1168      586

# %%
#------axis level function
sns.lineplot(data=df ,x='year',y='lifeExp')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
sns.relplot(data=df ,x='year',y='lifeExp',kind='line')

# %%
df = gap[gap['country'].isin(['India','Brazil','Germany'])]
df.head()
# Out:
#     country continent  year  lifeExp        pop    gdpPercap iso_alpha  \
# 168  Brazil  Americas  1952   50.917   56602560  2108.944355       BRA
# 169  Brazil  Americas  1957   53.285   65551171  2487.365989       BRA
# 170  Brazil  Americas  1962   55.665   76039390  3336.585802       BRA
# 171  Brazil  Americas  1967   57.632   88049823  3429.864357       BRA
# 172  Brazil  Americas  1972   59.504  100840058  4985.711467       BRA
#
#      iso_num
# 168       76
# 169       76
# 170       76
# 171       76
# 172       76

# %%
#hue 
sns.relplot(data=df ,x='year',y='lifeExp',kind='line',hue='country',style='continent',size='continent')

# %%
#--------facet plot works with figure and rel but not work with scatter and line

# %%
sns.relplot(data=tips,x='total_bill',y='tip',col='sex')

# %%
sns.relplot(data=tips,x='total_bill',y='tip',row='day',col='sex')

# %%
#col wrap

# %%
sns.relplot(data=gap,x='lifeExp',y='gdpPercap',kind='scatter',col='year',col_wrap=4)

# %%
#_____________distribution

# %%
#hist plot
#-----------fig = displot
#------------axis=his, kdepot, regplot

# %%
#plotting using univervariance
sns.histplot(data=tips,x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.displot(data=tips, x='total_bill',kind='hist')

# %%
#bins parameter
sns.displot(data=tips, x='total_bill',kind='hist',bins=10)
#bins ko control bhi kr ssakty hain

# %%
#categorical ke uppr bhi histogram kr sakty ho

# %%
sns.displot(data=tips, x='day',kind='hist') #countplot

# %%
#hue parameter
sns.displot(data=tips, x='tip',kind='hist',hue='sex')

# %%
#element-- step
sns.displot(data=tips, x='day',kind='hist',hue='sex',element='step')

# %%
#load data 
t= sns.load_dataset('titanic')
t.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.displot(data=t, x='age',kind='hist',hue='sex',element='step')

# %%
sns.displot(data=tips, x='tip',kind='hist',col='sex',element='step')
#facent---- hist ke sath km nhi krta

# %%
#kdeplot

# %%
sns.kdeplot(data=tips, x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(data=tips, x='total_bill',hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.displot(data=tips, x='total_bill',kind='kde')

# %%
#hue parameter
sns.displot(data=tips, x='total_bill',kind='kde',hue='sex',fill=True,height=10,aspect=2) #aspect (width ko height se 2 gunah bhra de ga 
#for fill the graph write fill = true

# %%
#----------regplot = yeh x and y axis ke dermiyan me trick ke lea use hota ha
#yeh baqion ke sath use hota hai

# %%
sns.kdeplot(data=tips, x='total_bill')
sns.rugplot(data=tips, x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
#bi vareient
sns.histplot(data=tips, x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#kde ke sath bhi km kr sakty hain
sns.kdeplot(data=tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#------Matrix plot

# %%
#heat map

# %%
df = gap.pivot(index='country',columns='year',values='lifeExp')

# %%
#axis size
plt.figure(figsize=(15,7))
sns.heatmap(df)
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
#sirf wohi europe country chahie
df = gap[gap['continent']=='Europe'].pivot(index='country',columns='year',values='lifeExp')

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df,annot=True,linewidth=0.5,cmap='viridis') 
#annot ka mtlb hai ke values show hongi
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
#cluster map
#iska mtlb hai similar columns ko aik sath kr deta hai or dis-similar ko aik sath

# %%
i = px.data.iris()

# %%
i.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  species_id
# 0           5.1          3.5           1.4          0.2  setosa           1
# 1           4.9          3.0           1.4          0.2  setosa           1
# 2           4.7          3.2           1.3          0.2  setosa           1
# 3           4.6          3.1           1.5          0.2  setosa           1
# 4           5.0          3.6           1.4          0.2  setosa           1

# %%
#jin columns ke uper clutering krna chahty ho uska naam bhejna hai
sns.clustermap(i.iloc[:,[0,1,2,3,]])

# %%
#these lines is called dendogram

# %%
#import dataset

# %%
#------categorical

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
iris = sns.load_dataset('iris')

# %%
#------(1)  strip plot (add some noise to improve readability 
#axis level
sns.stripplot(data=tips,x='day', y='total_bill',jitter=False)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#----using catplot for figure level function---
sns.catplot(data=tips,x='day', y='total_bill',kind='strip')

# %%
#jitter 
sns.catplot(data=tips,x='day', y='total_bill',kind='strip',jitter=1)

# %%
#-------(2) swarmplot (same as strip )
sns.catplot(data=tips,x='day', y='total_bill',kind='swarm',hue='sex')

# %%
#cate distribution

# %%
#----------(1) Box Plot

# %%
sns.boxplot(data=tips,x='day', y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#figure level catplot
sns.catplot(data=tips,x='day', y='total_bill',kind='box',hue='sex')

# %%
#single boxplot  -->  numerical col
#side by side columns chahie--
sns.boxplot(data=tips,y='total_bill')
# Out:
# <Axes: ylabel='total_bill'>

# %%
#----(2) voilin plot
#combination of KDE plot and Boxplot
sns.violinplot(data=tips,x='day', y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#--catplot
sns.catplot(data=tips,x='day', y='total_bill',kind='violin',hue='sex',split= True)

# %%
#----------Categorical estimated plot

# %%
#----(1) barplot

# %%
sns.barplot(data=tips,x='sex', y='total_bill',hue='smoker',estimator = np.std)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
#---- (2) point plot
sns.pointplot(data=tips,x='sex', y='total_bill',estimator = np.max , ci=None)
# Out:
# C:\Users\me\AppData\Local\Temp\ipykernel_9344\3743328381.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.pointplot(data=tips,x='sex', y='total_bill',estimator = np.max , ci=None)
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
#--- (3) count plot

sns.countplot(data=tips,x='sex',hue='day')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
#--facent

# %%
sns.catplot(data=tips,x='sex', y='total_bill',col='smoker',hue='sex',kind='box',row='time')

# %%
#-------regression

# %%
# 1- regplot ---axis level function

# %%
sns.regplot(data=tips, x='total_bill',y='tip') #lighter shadow of blue shows error
#hue parameter is me km nahi krta
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# 2- lmplot --figure level func

# %%
sns.lmplot(data=tips, x='total_bill',y='tip',hue='sex') #lighter shadow of blue shows error

# %%
#residplot
sns.residplot(data=tips, x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#----multiplot

# %%
# 1- facet grid ->regplot,catplot,displot

# %%
sns.catplot(data=tips, x='sex',y='total_bill',kind='violin',col='day',row='time')

# %%
#facet grid

# %%
g= sns.FacetGrid(data=tips,col='day',row='time')
g.map(sns.violinplot,'sex','total_bill')
plt.show()
# Out:
# d:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:718: UserWarning: Using the violinplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
# 2-   pair wise plot

# %%
sns.pairplot(iris,hue='species')

# %%
#pairgrid

# %%
g=sns.PairGrid(data=iris)
g.map(sns.scatterplot)

# %%
g=sns.PairGrid(data=iris,hue='species')
g.map(sns.histplot)
g.map_offdiag(sns.scatterplot)

# %%
g=sns.PairGrid(data=iris,hue='species')
g.map(sns.violinplot)
g.map_offdiag(sns.violinplot)

# %%
#joint--------------

# %%
sns.jointplot(data=tips,x='total_bill',y='tip',kind='scatter',hue='sex')

# %%
sns.jointplot(data=tips,x='total_bill',y='tip',kind='kde',hue='sex')

# %%
g= sns.JointGrid(data=tips,x='total_bill',y='tip')
g.plot(sns.scatterplot,sns.histplot)

# %%
g= sns.JointGrid(data=tips,x='total_bill',y='tip')
g.plot(sns.kdeplot,sns.boxplot)

# %%
#get dataset name
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']
