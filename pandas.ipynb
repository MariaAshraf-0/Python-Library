# %%
import numpy as np

# %%
import pandas as pd

# %%
movies = pd.read_csv('imdb-top-1000.csv')

# %%
movies.head(1)
# Out:
#                Series_Title Released_Year  Runtime  Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994      142  Drama          9.3
#
#          Director        Star1  No_of_Votes       Gross  Metascore
# 0  Frank Darabont  Tim Robbins      2343110  28341469.0       80.0

# %%
movies.dtypes
# Out:
# Series_Title      object
# Released_Year     object
# Runtime            int64
# Genre             object
# IMDB_Rating      float64
# Director          object
# Star1             object
# No_of_Votes        int64
# Gross            float64
# Metascore        float64
# dtype: object

# %%
movies.values
# Out:
# array([['The Shawshank Redemption', '1994', 142, ..., 2343110,
#         28341469.0, 80.0],
#        ['The Godfather', '1972', 175, ..., 1620367, 134966411.0, 100.0],
#        ['The Dark Knight', '2008', 152, ..., 2303232, 534858444.0, 84.0],
#        ...,
#        ['From Here to Eternity', '1953', 118, ..., 43374, 30500000.0,
#         85.0],
#        ['Lifeboat', '1944', 97, ..., 26471, 852142728.0, 78.0],
#        ['The 39 Steps', '1935', 86, ..., 51853, 302787539.0, 93.0]],
#       dtype=object)

# %%
movies.columns
# Out:
# Index(['Series_Title', 'Released_Year', 'Runtime', 'Genre', 'IMDB_Rating',
#        'Director', 'Star1', 'No_of_Votes', 'Gross', 'Metascore'],
#       dtype='object')

# %%
movies.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
movies.sample
# Out:
# <bound method NDFrame.sample of                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
# ...

# %%
movies.info
# Out:
# <bound method DataFrame.info of                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
# ...

# %%
#summary
movies.describe
# Out:
# <bound method NDFrame.describe of                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
# ...

# %%
#to check null value 
movies.isnull
# Out:
# <bound method DataFrame.isnull of                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
# ...

# %%
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
movies.std
# Out:
# <bound method DataFrame.std of                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
# ...

# %%
movies.head(5)
# Out:
#                Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994      142   Drama          9.3
# 1             The Godfather          1972      175   Crime          9.2
# 2           The Dark Knight          2008      152  Action          9.0
# 3    The Godfather: Part II          1974      202   Crime          9.0
# 4              12 Angry Men          1957       96   Crime          9.0
#
#                Director           Star1  No_of_Votes        Gross  Metascore
# 0        Frank Darabont     Tim Robbins      2343110   28341469.0       80.0
# 1  Francis Ford Coppola   Marlon Brando      1620367  134966411.0      100.0
# 2     Christopher Nolan  Christian Bale      2303232  534858444.0       84.0
# 3  Francis Ford Coppola       Al Pacino      1129952   57300000.0       90.0
# 4          Sidney Lumet     Henry Fonda       689845    4360000.0       96.0

# %%
movies ['Genre']
# Out:
# 0       Drama
# 1       Crime
# 2      Action
# 3       Crime
# 4       Crime
#         ...
# 995    Comedy
# 996     Drama
# 997     Drama
# 998     Drama
# 999     Crime
# Name: Genre, Length: 1000, dtype: object

# %%
movies [['Director' , 'Gross']]
# Out:
#                  Director        Gross
# 0          Frank Darabont   28341469.0
# 1    Francis Ford Coppola  134966411.0
# 2       Christopher Nolan  534858444.0
# 3    Francis Ford Coppola   57300000.0
# 4            Sidney Lumet    4360000.0
# ..                    ...          ...
# 995         Blake Edwards  679874270.0
# 996        George Stevens  195217415.0
# 997        Fred Zinnemann   30500000.0
# 998      Alfred Hitchcock  852142728.0
# 999      Alfred Hitchcock  302787539.0
#
# [1000 rows x 2 columns]

# %%
movies.iloc[2]
# Out:
# Series_Title       The Dark Knight
# Released_Year                 2008
# Runtime                        152
# Genre                       Action
# IMDB_Rating                    9.0
# Director         Christopher Nolan
# Star1               Christian Bale
# No_of_Votes                2303232
# Gross                  534858444.0
# Metascore                     84.0
# Name: 2, dtype: object

# %%
movies.shape
# Out:
# (1000, 10)

# %%
genres = movies.groupby('Genre')

# %%
genres.sum()
# Out:
#                                                 Series_Title  \
# Genre
# Action     The Dark KnightThe Lord of the Rings: The Retu...
# Adventure  InterstellarBack to the FutureInglourious Bast...
# Animation  Sen to Chihiro no kamikakushiThe Lion KingHota...
# Biography  Schindler's ListGoodfellasHamiltonThe Intoucha...
# Comedy     GisaengchungLa vita è bellaModern TimesCity Li...
# Crime      The GodfatherThe Godfather: Part II12 Angry Me...
# Drama      The Shawshank RedemptionFight ClubForrest Gump...
# Family     E.T. the Extra-TerrestrialWilly Wonka & the Ch...
# Fantasy                Das Cabinet des Dr. CaligariNosferatu
# Film-Noir   The Third ManThe Maltese FalconShadow of a Doubt
# Horror     PsychoAlienThe ThingThe ExorcistNight of the L...
# Mystery    MementoRear WindowVertigoShutter IslandKahaani...
# Thriller                                     Wait Until Dark
# Western    Il buono, il brutto, il cattivoOnce Upon a Tim...
#
# ...

# %%
genre.max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 genre.max()
#
# NameError: name 'genre' is not defined

# %%
#find the 3 genre by total earning (konse 3 genre hai jinho ne bht kmaai ki

movies.groupby('Genre').sum()['Gross'].sort_values(ascending = False).head(3)
# Out:
# Genre
# Drama     3.540997e+10
# Action    3.263226e+10
# Comedy    1.566387e+10
# Name: Gross, dtype: float64

# %%
movies.groupby('Genre')['Gross'].sum().sort_values(ascending = False).head(3)
# Out:
# Genre
# Drama     3.540997e+10
# Action    3.263226e+10
# Comedy    1.566387e+10
# Name: Gross, dtype: float64

# %%
#uska nam nikalna hai jiska imdb rating sab se zyda hai
movies.groupby('Genre')['IMDB_Rating'].mean().sort_values(ascending = False).head(1)
# Out:
# Genre
# Western    8.35
# Name: IMDB_Rating, dtype: float64

# %%
#find director with most popularity
movies.groupby('Director')['No_of_Votes'].sum().sort_values(ascending = False).head(1)
# Out:
# Director
# Christopher Nolan    11578345
# Name: No_of_Votes, dtype: int64

# %%
#find the number of movies done by each actor 
movies['Star1'].value_counts()
# Out:
# Star1
# Tom Hanks            12
# Robert De Niro       11
# Al Pacino            10
# Clint Eastwood       10
# Humphrey Bogart       9
#                      ..
# Phil Harris           1
# David Hemmings        1
# John Lennon           1
# Tallulah Bankhead     1
# Bruce Lee             1
# Name: count, Length: 660, dtype: int64

# %%
movies.groupby('Star1')['Series_Title'].count()
# Out:
# Star1
# Aamir Khan              7
# Aaron Taylor-Johnson    1
# Abhay Deol              1
# Abraham Attah           1
# Adam Driver             1
#                        ..
# Zbigniew Zamachowski    1
# Zooey Deschanel         1
# Çetin Tekindor          1
# Éric Toledano           1
# Ömer Faruk Sorak        1
# Name: Series_Title, Length: 660, dtype: int64

# %%
#movies me kitny gnre hai 
len(movies.groupby('Genre'))
# Out:
# 14

# %%
movies['Genre'].nunique()
# Out:
# 14

# %%
#hr group me ander kitny row mazood hai 
movies.groupby('Genre').size()
# Out:
# Genre
# Action       172
# Adventure     72
# Animation     82
# Biography     88
# Comedy       155
# Crime        107
# Drama        289
# Family         2
# Fantasy        2
# Film-Noir      3
# Horror        11
# Mystery       12
# Thriller       1
# Western        4
# dtype: int64

# %%
movies['Genre'].value_counts()
# Out:
# Genre
# Drama        289
# Action       172
# Comedy       155
# Crime        107
# Biography     88
# Animation     82
# Adventure     72
# Mystery       12
# Horror        11
# Western        4
# Film-Noir      3
# Fantasy        2
# Family         2
# Thriller       1
# Name: count, dtype: int64

# %%
#aik variable bna lo usme groupby store kr lo
#on the basis of genre 
genres = movies.groupby('Genre')

# %%
#ab har group ke first movie ko niklna hai 
genres.first()
# Out:
#                               Series_Title Released_Year  Runtime  \
# Genre
# Action                     The Dark Knight          2008      152
# Adventure                     Interstellar          2014      169
# Animation    Sen to Chihiro no kamikakushi          2001      125
# Biography                 Schindler's List          1993      195
# Comedy                        Gisaengchung          2019      132
# Crime                        The Godfather          1972      175
# Drama             The Shawshank Redemption          1994      142
# Family          E.T. the Extra-Terrestrial          1982      115
# Fantasy       Das Cabinet des Dr. Caligari          1920       76
# Film-Noir                    The Third Man          1949      104
# Horror                              Psycho          1960      109
# Mystery                            Memento          2000      113
# Thriller                   Wait Until Dark          1967      108
# ...

# %%
genres.last()
# Out:
#                                   Series_Title Released_Year  Runtime  \
# Genre
# Action                    Escape from Alcatraz          1979      112
# Adventure                       Kelly's Heroes          1970      144
# Animation                      The Jungle Book          1967       78
# Biography                     Midnight Express          1978      121
# Comedy                  Breakfast at Tiffany's          1961      115
# Crime                             The 39 Steps          1935       86
# Drama                                 Lifeboat          1944       97
# Family     Willy Wonka & the Chocolate Factory          1971      100
# Fantasy                              Nosferatu          1922       94
# Film-Noir                    Shadow of a Doubt          1943      108
# Horror                              The Others          2001      101
# Mystery                           Lost Highway          1997      134
# ...

# %%
genres.nth(6)
# Out:
#                                        Series_Title Released_Year  Runtime  \
# 16   Star Wars: Episode V - The Empire Strikes Back          1980      124
# 27                                            Se7en          1995      127
# 32                            It's a Wonderful Life          1946      130
# 66                                           WALL·E          2008       98
# 83                               The Great Dictator          1940      125
# 102                                      Braveheart          1995      178
# 118                              North by Northwest          1959      136
# 420                                          Sleuth          1972      138
# 724                                         Get Out          2017      104
#
#          Genre  IMDB_Rating              Director             Star1  \
# 16      Action          8.7        Irvin Kershner       Mark Hamill
# 27       Crime          8.6         David Fincher    Morgan Freeman
# ...

# %%
#get group (isko use kr ke hum particular group ki sari movies dekh sakty hain)
genres.get_group('Horror')
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 49                     Psycho          1960      109  Horror          8.5
# 75                      Alien          1979      117  Horror          8.4
# 271                 The Thing          1982      109  Horror          8.1
# 419              The Exorcist          1973      122  Horror          8.0
# 544  Night of the Living Dead          1968       96  Horror          7.9
# 707             The Innocents          1961      100  Horror          7.8
# 724                   Get Out          2017      104  Horror          7.7
# 844                 Halloween          1978       91  Horror          7.7
# 876         The Invisible Man          1933       71  Horror          7.7
# 932                       Saw          2004      103  Horror          7.6
# 948                The Others          2001      101  Horror          7.6
#
#                Director             Star1  No_of_Votes        Gross  Metascore
# ...

# %%
#also write 
movies[movies['Genre'] == 'Horror']
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 49                     Psycho          1960      109  Horror          8.5
# 75                      Alien          1979      117  Horror          8.4
# 271                 The Thing          1982      109  Horror          8.1
# 419              The Exorcist          1973      122  Horror          8.0
# 544  Night of the Living Dead          1968       96  Horror          7.9
# 707             The Innocents          1961      100  Horror          7.8
# 724                   Get Out          2017      104  Horror          7.7
# 844                 Halloween          1978       91  Horror          7.7
# 876         The Invisible Man          1933       71  Horror          7.7
# 932                       Saw          2004      103  Horror          7.6
# 948                The Others          2001      101  Horror          7.6
#
#                Director             Star1  No_of_Votes        Gross  Metascore
# ...

# %%
#groups
genres.groups
# Out:
# {'Action': [2, 5, 8, 10, 13, 14, 16, 29, 30, 31, 39, 42, 44, 55, 57, 59, 60, 63, 68, 72, 106, 109, 129, 130, 134, 140, 142, 144, 152, 155, 160, 161, 166, 168, 171, 172, 177, 181, 194, 201, 202, 216, 217, 223, 224, 236, 241, 262, 275, 294, 308, 320, 325, 326, 331, 337, 339, 340, 343, 345, 348, 351, 353, 356, 357, 362, 368, 369, 375, 376, 390, 410, 431, 436, 473, 477, 479, 482, 488, 493, 496, 502, 507, 511, 532, 535, 540, 543, 564, 569, 570, 573, 577, 582, 583, 602, 605, 608, 615, 623, ...], 'Adventure': [21, 47, 93, 110, 114, 116, 118, 137, 178, 179, 191, 193, 209, 226, 231, 247, 267, 273, 281, 300, 301, 304, 306, 323, 329, 361, 366, 377, 402, 406, 415, 426, 458, 470, 497, 498, 506, 513, 514, 537, 549, 552, 553, 566, 576, 604, 609, 618, 638, 647, 675, 681, 686, 692, 711, 713, 739, 755, 781, 797, 798, 851, 873, 884, 912, 919, 947, 957, 964, 966, 984, 991], 'Animation': [23, 43, 46, 56, 58, 61, 66, 70, 101, 135, 146, 151, 158, 170, 197, 205, 211, 213, 219, 229, 230, 242, 245, 246, 270, 
# ...

# %%
movies.groupby('Genre').groups
# Out:
# {'Action': [2, 5, 8, 10, 13, 14, 16, 29, 30, 31, 39, 42, 44, 55, 57, 59, 60, 63, 68, 72, 106, 109, 129, 130, 134, 140, 142, 144, 152, 155, 160, 161, 166, 168, 171, 172, 177, 181, 194, 201, 202, 216, 217, 223, 224, 236, 241, 262, 275, 294, 308, 320, 325, 326, 331, 337, 339, 340, 343, 345, 348, 351, 353, 356, 357, 362, 368, 369, 375, 376, 390, 410, 431, 436, 473, 477, 479, 482, 488, 493, 496, 502, 507, 511, 532, 535, 540, 543, 564, 569, 570, 573, 577, 582, 583, 602, 605, 608, 615, 623, ...], 'Adventure': [21, 47, 93, 110, 114, 116, 118, 137, 178, 179, 191, 193, 209, 226, 231, 247, 267, 273, 281, 300, 301, 304, 306, 323, 329, 361, 366, 377, 402, 406, 415, 426, 458, 470, 497, 498, 506, 513, 514, 537, 549, 552, 553, 566, 576, 604, 609, 618, 638, 647, 675, 681, 686, 692, 711, 713, 739, 755, 781, 797, 798, 851, 873, 884, 912, 919, 947, 957, 964, 966, 984, 991], 'Animation': [23, 43, 46, 56, 58, 61, 66, 70, 101, 135, 146, 151, 158, 170, 197, 205, 211, 213, 219, 229, 230, 242, 245, 246, 270, 
# ...

# %%
#functions 
#-------------------describe-------------------
genres.describe()
# Out:
#           Runtime                                                              \
#             count        mean        std    min     25%    50%     75%    max
# Genre
# Action      172.0  129.046512  28.500706   45.0  110.75  127.5  143.25  321.0
# Adventure    72.0  134.111111  33.317320   88.0  109.00  127.0  149.00  228.0
# Animation    82.0   99.585366  14.530471   71.0   90.00   99.5  106.75  137.0
# Biography    88.0  136.022727  25.514466   93.0  120.00  129.0  146.25  209.0
# Comedy      155.0  112.129032  22.946213   68.0   96.00  106.0  124.50  188.0
# Crime       107.0  126.392523  27.689231   80.0  106.50  122.0  141.50  229.0
# Drama       289.0  124.737024  27.740490   64.0  105.00  121.0  137.00  242.0
# Family        2.0  107.500000  10.606602  100.0  103.75  107.5  111.25  115.0
# Fantasy       2.0   85.000000  12.727922   76.0   80.50   85.0   89.50   94.0
# Film-Noir     3.0  104.000000   4.000000  100.0  102.00  104.0  106.00  108.0
# ...

# %%
genres.sample(2,replace=True)
# Out:
#                                           Series_Title Released_Year  Runtime  \
# 725                      Mission: Impossible - Fallout          2018      147
# 10   The Lord of the Rings: The Fellowship of the Ring          2001      178
# 304                       The Bridge on the River Kwai          1957      161
# 884                           The Peanut Butter Falcon          2019       97
# 578                           Kubo and the Two Strings          2016      101
# 640                       Les triplettes de Belleville          2003       80
# 545                                 The Lion in Winter          1968      134
# 940                                  Finding Neverland          2004      106
# 626                               Little Miss Sunshine          2006      101
# 481                                         The Artist          2011      100
# 108                                           Scarface          1983      170
# ...

# %%
genres.nunique()
# Out:
#            Series_Title  Released_Year  Runtime  IMDB_Rating  Director  Star1  \
# Genre
# Action              172             61       78           15       123    121
# Adventure            72             49       58           10        59     59
# Animation            82             35       41           11        51     77
# Biography            88             44       56           13        76     72
# Comedy              155             72       70           11       113    133
# Crime               106             56       65           14        86     85
# Drama               289             83       95           14       211    250
# Family                2              2        2            1         2      2
# Fantasy               2              2        2            2         2      2
# Film-Noir             3              3        3            3         3      3
# Horror               11             11       10            8        10     11
# ...

# %%
#agg methods (aik sath multiple aggregation like median etc laga sakty ho) 
#add dictionary 
genres.agg(
    {'Runtime' : 'mean',
    'IMDB_Rating' : 'mean',
    'No_of_Votes' : 'sum',
    'Gross' : 'sum',
    'Metascore' : 'min'}
)
# Out:
#               Runtime  IMDB_Rating  No_of_Votes         Gross  Metascore
# Genre
# Action     129.046512     7.949419     72282412  3.263226e+10       33.0
# Adventure  134.111111     7.937500     22576163  9.496922e+09       41.0
# Animation   99.585366     7.930488     21978630  1.463147e+10       61.0
# Biography  136.022727     7.938636     24006844  8.276358e+09       48.0
# Comedy     112.129032     7.901290     27620327  1.566387e+10       45.0
# Crime      126.392523     8.016822     33533615  8.452632e+09       47.0
# Drama      124.737024     7.957439     61367304  3.540997e+10       28.0
# Family     107.500000     7.800000       551221  4.391106e+08       67.0
# Fantasy     85.000000     8.000000       146222  7.827267e+08        NaN
# Film-Noir  104.000000     7.966667       367215  1.259105e+08       94.0
# Horror     102.090909     7.909091      3742556  1.034649e+09       46.0
# Mystery    119.083333     7.975000      4203004  1.256417e+09       52.0
# ...

# %%
#passing list (agr aik se zyda agg func apply krny honn aik genre pr)
#hum dict ki bajaye list pass kary gy
genres.agg(['min','max','mean'])

# %%
genres.agg(['min','max','mean'])

# %%
genres[['IMDB_Rating','Runtime', 'Gross']].agg(['min', 'max', 'mean'])
# Out:
#           IMDB_Rating                Runtime                         Gross  \
#                   min  max      mean     min  max        mean          min
# Genre
# Action            7.6  9.0  7.949419      45  321  129.046512       3296.0
# Adventure         7.6  8.6  7.937500      88  228  134.111111      61001.0
# Animation         7.6  8.6  7.930488      71  137   99.585366     128985.0
# Biography         7.6  8.9  7.938636      93  209  136.022727      21877.0
# Comedy            7.6  8.6  7.901290      68  188  112.129032       1305.0
# Crime             7.6  9.2  8.016822      80  229  126.392523       6013.0
# Drama             7.6  9.3  7.957439      64  242  124.737024       3600.0
# Family            7.8  7.8  7.800000     100  115  107.500000    4000000.0
# Fantasy           7.9  8.1  8.000000      76   94   85.000000  337574718.0
# Film-Noir         7.8  8.1  7.966667     100  108  104.000000     449191.0
# ...

# %%
#adding both synatx
genres.agg(
    {'Runtime' : ['min','mean'],
    'IMDB_Rating' : 'mean',
    'No_of_Votes' : ['sum','max'],
    'Gross' : 'sum',
    'Metascore' : 'min'}
)
# Out:
#           Runtime             IMDB_Rating No_of_Votes                  Gross  \
#               min        mean        mean         sum      max           sum
# Genre
# Action         45  129.046512    7.949419    72282412  2303232  3.263226e+10
# Adventure      88  134.111111    7.937500    22576163  1512360  9.496922e+09
# Animation      71   99.585366    7.930488    21978630   999790  1.463147e+10
# Biography      93  136.022727    7.938636    24006844  1213505  8.276358e+09
# Comedy         68  112.129032    7.901290    27620327   939631  1.566387e+10
# Crime          80  126.392523    8.016822    33533615  1826188  8.452632e+09
# Drama          64  124.737024    7.957439    61367304  2343110  3.540997e+10
# Family        100  107.500000    7.800000      551221   372490  4.391106e+08
# Fantasy        76   85.000000    8.000000      146222    88794  7.827267e+08
# Film-Noir     100  104.000000    7.966667      367215   158731  1.259105e+08
# ...

# %%
#looping on group 
df = pd.DataFrame(columns=movies.columns)

for group, data in genres:
    temp = data[data['IMDB_Rating'] == data['IMDB_Rating'].max()]
    df = pd.concat([df, temp], ignore_index=True)

df
# Out:
# C:\Users\me\AppData\Local\Temp\ipykernel_10652\3498910256.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, temp], ignore_index=True)
#                            Series_Title Released_Year Runtime      Genre  \
# 0                       The Dark Knight          2008     152     Action
# 1                          Interstellar          2014     169  Adventure
# 2         Sen to Chihiro no kamikakushi          2001     125  Animation
# 3                      Schindler's List          1993     195  Biography
# 4                          Gisaengchung          2019     132     Comedy
# 5                       La vita è bella          1997     116     Comedy
# ...

# %%
#split (apply) combine
genres.apply(min)
# Out:
# C:\Users\me\AppData\Local\Temp\ipykernel_10652\2917867842.py:2: FutureWarning: The provided callable <built-in function min> is currently using np.minimum.reduce. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string np.minimum.reduce instead.
#   genres.apply(min)
# C:\Users\me\AppData\Local\Temp\ipykernel_10652\2917867842.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   genres.apply(min)
#                               Series_Title Released_Year  Runtime      Genre  \
# Genre
# Action                                 300          1924       45     Action
# ...

# %%
#find karna hai k kitni movies hai jinka name A se shuru hota hai 
#isko find karne ke lea hum apna aik function bnae gy 
#------------------------------------------------

def finder(group):
    return (group['Series_Title'].str.startswith('A').sum())

# %%
#------call apply function on the top of genre function-----
genres.apply(finder)
# Out:
# C:\Users\me\AppData\Local\Temp\ipykernel_10652\3760438785.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   genres.apply(finder)
# Genre
# Action       10
# Adventure     2
# Animation     2
# Biography     9
# Comedy       14
# Crime         4
# Drama        21
# Family        0
# Fantasy       0
# Film-Noir     0
# Horror        1
# Mystery       0
# Thriller      0
# Western       0
# dtype: int64

# %%
#har movie ke samany ak ranking dena hai imdb ki basis per 
#------------sab ka groups ka like action , comedy ka alag rank ho ga 
def rank_movie(group):
    group['genre_rank']=group['IMDB_Rating'].rank(ascending = False)
    return group

# %%
genres.apply(rank_movie)
# Out:
# C:\Users\me\AppData\Local\Temp\ipykernel_10652\2409710219.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   genres.apply(rank_movie)
#                                                    Series_Title Released_Year  \
# Genre
# Action   2                                      The Dark Knight          2008
#          5        The Lord of the Rings: The Return of the King          2003
#          8                                            Inception          2010
#          10   The Lord of the Rings: The Fellowship of the Ring          2001
#          13               The Lord of the Rings: The Two Towers          2002
# ...

# %%
#---groupby on multiple columns
duo = movies.groupby(['Director' ,  'Star1'])
duo
#----size
duo.size()
# Out:
# Director             Star1
# Aamir Khan           Amole Gupte       1
# Aaron Sorkin         Eddie Redmayne    1
# Abdellatif Kechiche  Léa Seydoux       1
# Abhishek Chaubey     Shahid Kapoor     1
# Abhishek Kapoor      Amit Sadh         1
#                                       ..
# Zaza Urushadze       Lembit Ulfsak     1
# Zoya Akhtar          Hrithik Roshan    1
#                      Vijay Varma       1
# Çagan Irmak          Çetin Tekindor    1
# Ömer Faruk Sorak     Cem Yilmaz        1
# Length: 898, dtype: int64

# %%
#getgroup 
duo.get_group(('Aamir Khan','Amole Gupte'))
# Out:
#         Series_Title Released_Year  Runtime  Genre  IMDB_Rating    Director  \
# 65  Taare Zameen Par          2007      165  Drama          8.4  Aamir Khan
#
#           Star1  No_of_Votes      Gross  Metascore
# 65  Amole Gupte       168895  1223869.0        NaN

# %%
#---find the most earning actor-> director combo 
duo['Gross'].sum().sort_values(ascending = False).head(1)
# Out:
# Director        Star1
# Akira Kurosawa  Toshirô Mifune    2.999877e+09
# Name: Gross, dtype: float64

# %%
#find the best combo of actor and genre in terms of metascore(avg)
movies.groupby([ 'Star1', 'Genre'])['Metascore'].mean().reset_index().sort_values('Metascore',ascending = False).head(5)
# Out:
#                Star1      Genre  Metascore
# 606    Peter O'Toole  Adventure      100.0
# 590     Orson Welles      Drama      100.0
# 77       Bertil Guve      Drama      100.0
# 230   Ellar Coltrane      Drama      100.0
# 329  Humphrey Bogart      Drama      100.0

# %%
#agg on multiple groupby
duo.agg(['min','max'])
# Out:
#                                                   Series_Title  \
#                                                            min
# Director            Star1
# Aamir Khan          Amole Gupte               Taare Zameen Par
# Aaron Sorkin        Eddie Redmayne  The Trial of the Chicago 7
# Abdellatif Kechiche Léa Seydoux                 La vie d'Adèle
# Abhishek Chaubey    Shahid Kapoor                  Udta Punjab
# Abhishek Kapoor     Amit Sadh                      Kai po che!
# ...                                                        ...
# Zaza Urushadze      Lembit Ulfsak                  Mandariinid
# Zoya Akhtar         Hrithik Roshan    Zindagi Na Milegi Dobara
#                     Vijay Varma                      Gully Boy
# Çagan Irmak         Çetin Tekindor              Babam ve Oglum
# Ömer Faruk Sorak    Cem Yilmaz                        G.O.R.A.
#
#                                                                Released_Year  \
# ...

# %%
###--------------Now work with different Dataset----------------####

# %%
#Exercise

# %%
ipl = pd.read_csv('deliveries.csv')

# %%
ipl.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
#find the top 10 batsman in term of runs
ipl.groupby('batsman')['batsman_runs'].sum().sort_values(ascending = False).head(10)
# Out:
# batsman
# V Kohli           5434
# SK Raina          5415
# RG Sharma         4914
# DA Warner         4741
# S Dhawan          4632
# CH Gayle          4560
# MS Dhoni          4477
# RV Uthappa        4446
# AB de Villiers    4428
# G Gambhir         4223
# Name: batsman_runs, dtype: int64

# %%
#find the batsman with max no of sixes 
six = ipl[ipl['batsman_runs'] == 6]
six.groupby('batsman')['batsman'].count().sort_values(ascending = False)
# Out:
# batsman
# CH Gayle          327
# AB de Villiers    214
# MS Dhoni          207
# SK Raina          195
# RG Sharma         194
#                  ...
# AN Ahmed            1
# AD Mascarenhas      1
# TA Boult            1
# T Kohli             1
# TS Mills            1
# Name: batsman, Length: 336, dtype: int64

# %%
type(ipl)
# Out:
# pandas.core.frame.DataFrame

# %%
#sirf six and four run dekhny hon
tem_def= ipl[ipl['over']>15]
tem_def[(tem_def['batsman_runs'] == 4) | (tem_def['batsman_runs'] == 6)]
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 101            1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 105            1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 109            1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 114            1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 115            1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179052     11415       2  Chennai Super Kings               Mumbai Indians
# 179061     11415       2  Chennai Super Kings               Mumbai Indians
# 179062     11415       2  Chennai Super Kings               Mumbai Indians
# 179063     11415       2  Chennai Super Kings               Mumbai Indians
# 179071     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
tem_def.groupby('batsman')['batsman'].count().sort_values(ascending=False).head(1).index[0]
# Out:
# 'MS Dhoni'

# %%
#find v kholi record against in all teams 
tem_def = ipl[ipl['batsman']== 'V Kohli']
tem_def.groupby('bowling_team')['batsman_runs'].sum().reset_index()
# Out:
#                bowling_team  batsman_runs
# 0       Chennai Super Kings           749
# 1           Deccan Chargers           306
# 2            Delhi Capitals            66
# 3          Delhi Daredevils           763
# 4             Gujarat Lions           283
# 5           Kings XI Punjab           636
# 6      Kochi Tuskers Kerala            50
# 7     Kolkata Knight Riders           675
# 8            Mumbai Indians           628
# 9             Pune Warriors           128
# 10         Rajasthan Royals           370
# 11   Rising Pune Supergiant            83
# 12  Rising Pune Supergiants           188
# 13      Sunrisers Hyderabad           509

# %%
# ap aik batsman ka name do gy wo batye ga ke uska runs kitny hain 
temp_def = ipl[ipl['batsman'] == 'V Kohli']
temp_def.groupby('match_id')['batsman_runs'].sum().sort_values(ascending=False).head(1).values[0]
# Out:
# np.int64(113)

# %%
def highest(batsman):
    temp_def = ipl[ipl['batsman'] == batsman]
    return temp_def.groupby('match_id')['batsman_runs'].sum().sort_values(ascending=False).head(1).values[0]

# %%
highest ('SR Watson')
# Out:
# np.int64(121)

# %%
students = pd.read_csv('students.csv')
students
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 1            2         Esha Butala        1
# 2            3      Parveen Bhalla        3
# 3            4         Marlo Dugal       14
# 4            5         Kusum Bahri        6
# 5            6  Lakshmi Contractor       10
# 6            7        Tarun Thaker        9
# 7            8      Radheshyam Dey        5
# 8            9   Nitika Chatterjee        4
# 9           10      Aayushman Sant        8
# 10          11  David Mukhopadhyay       20
# 11          12          Radha Dutt       19
# 12          13      Munni Varghese       24
# 13          14    Pranab Natarajan       22
# 14          15           Preet Sha       16
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 18          19        Qabeel Raman       12
# 19          20       Hanuman Hegde       11
# ...

# %%
dec= pd.read_csv('reg-month2.csv')
dec
# Out:
#     student_id  course_id
# 0            3          5
# 1           16          7
# 2           12         10
# 3           12          1
# 4           14          9
# 5            7          7
# 6            7          2
# 7           16          3
# 8           17         10
# 9           11          8
# 10          14          6
# 11          12          5
# 12          12          7
# 13          18          8
# 14           1         10
# 15           1          9
# 16           2          5
# 17           7          6
# 18          22          5
# 19          22          6
# 20          23          9
# 21          23          5
# 22          14          4
# 23          14          1
# 24          11         10
# 25          42          9
# 26          50          8
# 27          38          1

# %%
course = pd.read_csv('courses.csv')
students = pd.read_csv('students.csv')
delivery = pd.read_csv('deliveries.csv')
matches= pd.read_csv('matches.csv')

nov = pd.read_csv('reg-month1.csv')
dec= pd.read_csv('reg-month2.csv')

# %%
combine = pd.concat([nov,dec],ignore_index=True)
combine
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3
# 25           3          5
# 26          16          7
# 27          12         10
# 28          12          1
# 29          14          9
# 30           7          7
# 31           7          2
# 32          16          3
# 33          17         10
# ...

# %%
#append ko pandas support nahi krta

# %%
# this is multi-indexing data frame
combine = pd.concat([nov,dec],keys=['Nov','Dec'])
combine
# Out:
#         student_id  course_id
# Nov 0           23          1
#     1           15          5
#     2           18          6
#     3           23          4
#     4           16          9
#     5           18          1
#     6            1          1
#     7            7          8
#     8           22          3
#     9           15          1
#     10          19          4
#     11           1          6
#     12           7         10
#     13          11          7
#     14          13          3
#     15          24          4
#     16          21          1
#     17          16          5
#     18          23          3
#     19          17          7
#     20          23          6
#     21          25          1
#     22          19          2
#     23          25         10
#     24           3          3
# Dec 0            3          5
#     1           16          7
#     2           12         10
#     3           12          1
#     4           14          9
# ...

# %%
combine.loc[('Nov',4)]
# Out:
# student_id    16
# course_id      9
# Name: (Nov, 4), dtype: int64

# %%
#----------Horizontal-------
pd.concat([nov,dec],axis=1)
# Out:
#     student_id  course_id  student_id  course_id
# 0         23.0        1.0           3          5
# 1         15.0        5.0          16          7
# 2         18.0        6.0          12         10
# 3         23.0        4.0          12          1
# 4         16.0        9.0          14          9
# 5         18.0        1.0           7          7
# 6          1.0        1.0           7          2
# 7          7.0        8.0          16          3
# 8         22.0        3.0          17         10
# 9         15.0        1.0          11          8
# 10        19.0        4.0          14          6
# 11         1.0        6.0          12          5
# 12         7.0       10.0          12          7
# 13        11.0        7.0          18          8
# 14        13.0        3.0           1         10
# 15        24.0        4.0           1          9
# 16        21.0        1.0           2          5
# 17        16.0        5.0           7          6
# ...

# %%
#------------Joining----------///////////
students
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 1            2         Esha Butala        1
# 2            3      Parveen Bhalla        3
# 3            4         Marlo Dugal       14
# 4            5         Kusum Bahri        6
# 5            6  Lakshmi Contractor       10
# 6            7        Tarun Thaker        9
# 7            8      Radheshyam Dey        5
# 8            9   Nitika Chatterjee        4
# 9           10      Aayushman Sant        8
# 10          11  David Mukhopadhyay       20
# 11          12          Radha Dutt       19
# 12          13      Munni Varghese       24
# 13          14    Pranab Natarajan       22
# 14          15           Preet Sha       16
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 18          19        Qabeel Raman       12
# 19          20       Hanuman Hegde       11
# ...

# %%
#/////---------------INNER JOIN---------///////
students.merge(dec,how='inner',on='student_id')
# Out:
#     student_id                name  partner  course_id
# 0            1       Kailash Harjo       23         10
# 1            1       Kailash Harjo       23          9
# 2            2         Esha Butala        1          5
# 3            3      Parveen Bhalla        3          5
# 4            7        Tarun Thaker        9          7
# 5            7        Tarun Thaker        9          2
# 6            7        Tarun Thaker        9          6
# 7           11  David Mukhopadhyay       20          8
# 8           11  David Mukhopadhyay       20         10
# 9           12          Radha Dutt       19         10
# 10          12          Radha Dutt       19          1
# 11          12          Radha Dutt       19          5
# 12          12          Radha Dutt       19          7
# 13          14    Pranab Natarajan       22          9
# 14          14    Pranab Natarajan       22          6
# 15          14    Pranab Natarajan       22          4
# ...

# %%
##////----------------LEFT JOIN--------------------
course.merge(dec,how='left',on='course_id')
# Out:
#     course_id       course_name  price  student_id
# 0           1            python   2499        12.0
# 1           1            python   2499        14.0
# 2           1            python   2499        38.0
# 3           2               sql   3499         7.0
# 4           3     data analysis   4999        16.0
# 5           4  machine learning   9999        14.0
# 6           5           tableau   2499         3.0
# 7           5           tableau   2499        12.0
# 8           5           tableau   2499         2.0
# 9           5           tableau   2499        22.0
# 10          5           tableau   2499        23.0
# 11          6          power bi   1899        14.0
# 12          6          power bi   1899         7.0
# 13          6          power bi   1899        22.0
# 14          7          ms sxcel   1599        16.0
# 15          7          ms sxcel   1599         7.0
# 16          7          ms sxcel   1599        12.0
# ...

# %%
##////////////------------RIGHT JOIN------------------
temp= pd.DataFrame({
    'student_id': [26,27,28],
    'name': ['ahmed','noor','aliyan'],
    'partner':[28,26,17]
})
students = pd.concat([students,temp],ignore_index=True)

# %%
students.merge(dec,how='right',on='student_id')
# Out:
#     student_id                name  partner  course_id
# 0            3      Parveen Bhalla      3.0          5
# 1           16        Elias Dodiya     25.0          7
# 2           12          Radha Dutt     19.0         10
# 3           12          Radha Dutt     19.0          1
# 4           14    Pranab Natarajan     22.0          9
# 5            7        Tarun Thaker      9.0          7
# 6            7        Tarun Thaker      9.0          2
# 7           16        Elias Dodiya     25.0          3
# 8           17        Yasmin Palan      7.0         10
# 9           11  David Mukhopadhyay     20.0          8
# 10          14    Pranab Natarajan     22.0          6
# 11          12          Radha Dutt     19.0          5
# 12          12          Radha Dutt     19.0          7
# 13          18     Fardeen Mahabir     13.0          8
# 14           1       Kailash Harjo     23.0         10
# 15           1       Kailash Harjo     23.0          9
# ...

# %%
#//////////////-----------outer join-------------------
students.merge(dec,how='outer',on='student_id')
# Out:
#     student_id                name  partner  course_id
# 0            1       Kailash Harjo     23.0       10.0
# 1            1       Kailash Harjo     23.0        9.0
# 2            2         Esha Butala      1.0        5.0
# 3            3      Parveen Bhalla      3.0        5.0
# 4            4         Marlo Dugal     14.0        NaN
# 5            5         Kusum Bahri      6.0        NaN
# 6            6  Lakshmi Contractor     10.0        NaN
# 7            7        Tarun Thaker      9.0        7.0
# 8            7        Tarun Thaker      9.0        2.0
# 9            7        Tarun Thaker      9.0        6.0
# 10           8      Radheshyam Dey      5.0        NaN
# 11           9   Nitika Chatterjee      4.0        NaN
# 12          10      Aayushman Sant      8.0        NaN
# 13          11  David Mukhopadhyay     20.0        8.0
# 14          11  David Mukhopadhyay     20.0       10.0
# 15          12          Radha Dutt     19.0       10.0
# ...

# %%
#----------------------------Questions for practice----------------------------

# %%
# QUESTION 1 
## find total revenue generated by the company
total= regs.merge(course , how= 'inner',on='course_id')['price'].sum()
total
# Out:
# np.int64(24585)

# %%
#Question 2 
## find month by month revenue (btana hai ke nov or dec me kitna kamaya hai )

tem = pd.concat([nov,dec],keys= ['Nov','Dec']).reset_index()
tem.merge(course,on='course_id').groupby('level_0')['price'].sum()
# Out:
# level_0
# Dec    65072
# Nov    89175
# Name: price, dtype: int64

# %%
#Question 3
# print reg table ( name , course_name , price)

regs.merge(students , on='student_id').merge(course,on='course_id')[['name','course_name','price']]
# Out:
#               name    course_name  price
# 0            ahmed       power bi   1899
# 1  Shashank D’Alia         pandas   1099
# 2   Radheshyam Dey  data analysis   4999
# 3   Chhavi Lachman          Numpy    699
# 4            ahmed         plotly    699
# 5   Munni Varghese          Numpy    699
# 6   Chhavi Lachman       power bi   1899
# 7   Chhavi Lachman          Numpy    699

# %%
#Question 4
#--plot bar chart for revenue /course

import matplotlib as plt
dec.merge(course,on='course_id').groupby('course_name')['price'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='course_name'>

# %%
#Question 5 
# jinho ne nov and dec dono me kisi course me enroll kea hai 
csi= np.intersect1d(nov['student_id'],dec['student_id'])
csi
# Out:
# array([ 1,  3,  7, 11, 16, 17, 18, 22, 23])

# %%
students[students['student_id'].isin(csi)]
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 2            3      Parveen Bhalla        3
# 6            7        Tarun Thaker        9
# 10          11  David Mukhopadhyay       20
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 21          22          Yash Sethi       21
# 22          23      Chhavi Lachman       18

# %%
#question 6 
#find student who did not enroll into any course
std_id_list= np.setdiff1d(students['student_id'],dec['student_id'])
students[students['student_id'].isin(std_id_list)].shape[0]
# Out:
# 16

# %%
#-------------////////---------SELF JOIN----------------------------------------
#iska mtlb hai ke hum isko khudi ke sath join kr de gy (mtb apne table ke sath)
students.merge(students,how='inner',left_on='partner',right_on='student_id')[['name_x','name_y']]
# Out:
#                 name_x              name_y
# 0        Kailash Harjo      Chhavi Lachman
# 1          Esha Butala       Kailash Harjo
# 2       Parveen Bhalla      Parveen Bhalla
# 3          Marlo Dugal    Pranab Natarajan
# 4          Kusum Bahri  Lakshmi Contractor
# 5   Lakshmi Contractor      Aayushman Sant
# 6         Tarun Thaker   Nitika Chatterjee
# 7       Radheshyam Dey         Kusum Bahri
# 8    Nitika Chatterjee         Marlo Dugal
# 9       Aayushman Sant      Radheshyam Dey
# 10  David Mukhopadhyay       Hanuman Hegde
# 11          Radha Dutt        Qabeel Raman
# 12      Munni Varghese        Radhika Suri
# 13    Pranab Natarajan          Yash Sethi
# 14           Preet Sha        Elias Dodiya
# 15        Elias Dodiya     Shashank D’Alia
# 16        Yasmin Palan        Tarun Thaker
# 17     Fardeen Mahabir      Munni Varghese
# 18        Qabeel Raman          Radha Dutt
# 19       Hanuman Hegde  David Mukhopadhyay
# 20          Seema Kota           Preet Sha
# ...

# %%
#------question 8
#find the top 3 student name who did most number enrollment 

dec.merge(students, on ='student_id')['name'].groupby(['student_id','name'])['name'].count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[314], line 4
#       1 #------question 8
#       2 #find the top 3 student name who did most number enrollment
# ----> 4 dec.merge(students, on ='student_id')['name'].groupby(['student_id','name'])['name'].count()
#
# File d:\ProgramData\anaconda3\Lib\site-packages\pandas\core\series.py:2247, in Series.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    2244     raise TypeError("as_index=False only valid with DataFrame")
#    2245 axis = self._get_axis_number(axis)
# -> 2247 return SeriesGroupBy(
#    2248     obj=self,
#    2249     keys=by,
#    2250     axis=axis,
#    2251     level=level,
#    2252     as_index=as_index,
#    2253     sort=sort,
#    2254     group_keys=group_keys,
#    2255     observed=observed,
#    2256     dropna=dropna,
#    2257 )
#
# ...

# %%
students
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 1            2         Esha Butala        1
# 2            3      Parveen Bhalla        3
# 3            4         Marlo Dugal       14
# 4            5         Kusum Bahri        6
# 5            6  Lakshmi Contractor       10
# 6            7        Tarun Thaker        9
# 7            8      Radheshyam Dey        5
# 8            9   Nitika Chatterjee        4
# 9           10      Aayushman Sant        8
# 10          11  David Mukhopadhyay       20
# 11          12          Radha Dutt       19
# 12          13      Munni Varghese       24
# 13          14    Pranab Natarajan       22
# 14          15           Preet Sha       16
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 18          19        Qabeel Raman       12
# 19          20       Hanuman Hegde       11
# ...

# %%
dec
# Out:
#     student_id  course_id
# 0            3          5
# 1           16          7
# 2           12         10
# 3           12          1
# 4           14          9
# 5            7          7
# 6            7          2
# 7           16          3
# 8           17         10
# 9           11          8
# 10          14          6
# 11          12          5
# 12          12          7
# 13          18          8
# 14           1         10
# 15           1          9
# 16           2          5
# 17           7          6
# 18          22          5
# 19          22          6
# 20          23          9
# 21          23          5
# 22          14          4
# 23          14          1
# 24          11         10
# 25          42          9
# 26          50          8
# 27          38          1

# %%
type(students)
# Out:
# pandas.core.frame.DataFrame

# %%
nov.merge(students, on='student_id').groupby(['student_id', 'name'])['name'].count().sort_values(ascending=False).head(3)
# Out:
# student_id  name
# 23          Chhavi Lachman    4
# 7           Tarun Thaker      2
# 1           Kailash Harjo     2
# Name: name, dtype: int64

# %%
#--------------------alternate merge syntax 
pd.merge(students,dec , how ='inner',on='student_id')
# Out:
#     student_id                name  partner  course_id
# 0            1       Kailash Harjo       23         10
# 1            1       Kailash Harjo       23          9
# 2            2         Esha Butala        1          5
# 3            3      Parveen Bhalla        3          5
# 4            7        Tarun Thaker        9          7
# 5            7        Tarun Thaker        9          2
# 6            7        Tarun Thaker        9          6
# 7           11  David Mukhopadhyay       20          8
# 8           11  David Mukhopadhyay       20         10
# 9           12          Radha Dutt       19         10
# 10          12          Radha Dutt       19          1
# 11          12          Radha Dutt       19          5
# 12          12          Radha Dutt       19          7
# 13          14    Pranab Natarajan       22          9
# 14          14    Pranab Natarajan       22          6
# 15          14    Pranab Natarajan       22          4
# ...

# %%
#-------------- Multi-indexing-------------------

# %%
 ts1= pd.read_csv('TS1.csv')
ts2 = pd.read_csv('TS2.csv')

# %%
ts1.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  12/24/22  12/25/22  12/26/22  \
# 0        0        0        0        0  ...    207310    207399    207438
# 1        0        0        0        0  ...    333749    333749    333751
# 2        0        0        0        0  ...    271194    271198    271198
# 3        0        0        0        0  ...     47686     47686     47686
# 4        0        0        0        0  ...    104973    104973    104973
#
#    12/27/22  12/28/22  12/29/22  12/30/22  12/31/22  1/1/23  1/2/23
# ...

# %%
ts1.shape
# Out:
# (289, 1081)

# %%
ts2.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  12/24/22  12/25/22  12/26/22  \
# 0        0        0        0        0  ...      7845      7846      7846
# 1        0        0        0        0  ...      3595      3595      3595
# 2        0        0        0        0  ...      6881      6881      6881
# 3        0        0        0        0  ...       165       165       165
# 4        0        0        0        0  ...      1928      1928      1928
#
#    12/27/22  12/28/22  12/29/22  12/30/22  12/31/22  1/1/23  1/2/23
# ...

# %%
#---- How to create multiindexing object 
#~~~~~~~ from tuple ~~~~~~~~~~~~~~
i_val = [('cse',2019),('cse',2020),('cse',2021),('cse',2022),('ece',2019),('ece',2020),('ece',2021),('ece',2022)]
multiindex = pd.MultiIndex.from_tuples(i_val)
multiindex.levels[0]
#~~~~~~~ from product ~~~~~~~~~~~~~
pd.MultiIndex.from_product([['cse', 'ece'],[2019,2020,2021,2022]])
# Out:
# MultiIndex([('cse', 2019),
#             ('cse', 2020),
#             ('cse', 2021),
#             ('cse', 2022),
#             ('ece', 2019),
#             ('ece', 2020),
#             ('ece', 2021),
#             ('ece', 2022)],
#            )

# %%
#create a series using multi-indexing 
s= pd.Series([1,2,3,4,5,6,7,8],index=multiindex)
s
# Out:
# cse  2019    1
#      2020    2
#      2021    3
#      2022    4
# ece  2019    5
#      2020    6
#      2021    7
#      2022    8
# dtype: int64

# %%
s['cse']
# Out:
# 2019    1
# 2020    2
# 2021    3
# 2022    4
# dtype: int64

# %%
#unstack
m= s.unstack()

# %%
#stack 
m.stack()
# Out:
# cse  2019    1
#      2020    2
#      2021    3
#      2022    4
# ece  2019    5
#      2020    6
#      2021    7
#      2022    8
# dtype: int64

# %%
#---multi-indexing dataframe --- 
#^^^^^^^^^^^^^^^____________ to represent 3D into 2D__________________-^^^^^^^^^^^^^^^^^^^

b=pd.DataFrame(
 [
    [1,2],
    [2,0],
    [9,3],
    [23,66],
    [5,10],
    [99,45],
    [3,9],
    [22,8],
 ],
 index = multiindex,
 columns = ['avg_pkg','stdents']
)
b
# Out:
#           avg_pkg  stdents
# cse 2019        1        2
#     2020        2        0
#     2021        9        3
#     2022       23       66
# ece 2019        5       10
#     2020       99       45
#     2021        3        9
#     2022       22        8

# %%
b.loc['ece']
# Out:
#       avg_pkg  stdents
# 2019        5       10
# 2020       99       45
# 2021        3        9
# 2022       22        8

# %%
b.loc[:,'avg_pkg']
# Out:
# cse  2019     1
#      2020     2
#      2021     9
#      2022    23
# ece  2019     5
#      2020    99
#      2021     3
#      2022    22
# Name: avg_pkg, dtype: int64

# %%
b.loc['cse']
# Out:
#       avg_pkg  stdents
# 2019        1        2
# 2020        2        0
# 2021        9        3
# 2022       23       66

# %%
#multi indexing on both row and coolumns 
b_df3 = pd.DataFrame(
    [
        [1,2,0,0],
        [3,4,0,0],
        [5,6,0,0],
        [7,8,0,0],
        [9,10,0,0],  
        [11,12,0,0],
        [13,14,0,0],
        [15,16,0,0],
    ],
    index = multiindex,
    columns = pd.MultiIndex.from_product([['dehli', 'lahore'],['avg_pkg','stdents']])
)
b_df3
# Out:
#            dehli          lahore
#          avg_pkg stdents avg_pkg stdents
# cse 2019       1       2       0       0
#     2020       3       4       0       0
#     2021       5       6       0       0
#     2022       7       8       0       0
# ece 2019       9      10       0       0
#     2020      11      12       0       0
#     2021      13      14       0       0
#     2022      15      16       0       0

# %%
o= b.unstack().unstack() #data frame se series bn jaye ga jb ap do bar unstack chlao gy 
# phli dfa 'unstack' me aik col khtm hoga 
#dsri dfa 'unstack' me baqi ky  bachy cols bhi khtm ho jaye gy
o
# Out:
# avg_pkg  2019  cse     1
#                ece     5
#          2020  cse     2
#                ece    99
#          2021  cse     9
#                ece     3
#          2022  cse    23
#                ece    22
# stdents  2019  cse     2
#                ece    10
#          2020  cse     0
#                ece    45
#          2021  cse     3
#                ece     9
#          2022  cse    66
#                ece     8
# dtype: int64

# %%
b.unstack().stack() #is se orignal wla hi mily ga
# Out:
# C:\Users\me\AppData\Local\Temp\ipykernel_10652\1843358160.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   b.unstack().stack() #is se orignal wla hi mily ga
#           avg_pkg  stdents
# cse 2019        1        2
#     2020        2        0
#     2021        9        3
#     2022       23       66
# ece 2019        5       10
#     2020       99       45
#     2021        3        9
#     2022       22        8

# %%
b.unstack()
# Out:
#     avg_pkg                stdents
#        2019 2020 2021 2022    2019 2020 2021 2022
# cse       1    2    9   23       2    0    3   66
# ece       5   99    3   22      10   45    9    8

# %%
b_df3.unstack()
# Out:
#       dehli                                        lahore                 \
#     avg_pkg                stdents                avg_pkg
#        2019 2020 2021 2022    2019 2020 2021 2022    2019 2020 2021 2022
# cse       1    3    5    7       2    4    6    8       0    0    0    0
# ece       9   11   13   15      10   12   14   16       0    0    0    0
#
#
#     stdents
#        2019 2020 2021 2022
# cse       0    0    0    0
# ece       0    0    0    0

# %%
b_df3.unstack().unstack()
# Out:
# dehli   avg_pkg  2019  cse     1
#                        ece     9
#                  2020  cse     3
#                        ece    11
#                  2021  cse     5
#                        ece    13
#                  2022  cse     7
#                        ece    15
#         stdents  2019  cse     2
#                        ece    10
#                  2020  cse     4
#                        ece    12
#                  2021  cse     6
#                        ece    14
#                  2022  cse     8
#                        ece    16
# lahore  avg_pkg  2019  cse     0
#                        ece     0
#                  2020  cse     0
#                        ece     0
#                  2021  cse     0
#                        ece     0
#                  2022  cse     0
#                        ece     0
#         stdents  2019  cse     0
#                        ece     0
#                  2020  cse     0
#                        ece     0
# ...

# %%
b_df3.stack().stack()
# Out:
# C:\Users\me\AppData\Local\Temp\ipykernel_10652\926868461.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   b_df3.stack().stack()
# cse  2019  avg_pkg  dehli      1
#                     lahore     0
#            stdents  dehli      2
#                     lahore     0
#      2020  avg_pkg  dehli      3
#                     lahore     0
#            stdents  dehli      4
#                     lahore     0
#      2021  avg_pkg  dehli      5
#                     lahore     0
#            stdents  dehli      6
#                     lahore     0
#      2022  avg_pkg  dehli      7
#                     lahore     0
#            stdents  dehli      8
#                     lahore     0
# ece  2019  avg_pkg  dehli      9
#                     lahore     0
# ...

# %%
b_df3.stack()
# Out:
# C:\Users\me\AppData\Local\Temp\ipykernel_10652\2461364046.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   b_df3.stack()
#                   dehli  lahore
# cse 2019 avg_pkg      1       0
#          stdents      2       0
#     2020 avg_pkg      3       0
#          stdents      4       0
#     2021 avg_pkg      5       0
#          stdents      6       0
#     2022 avg_pkg      7       0
#          stdents      8       0
# ece 2019 avg_pkg      9       0
#          stdents     10       0
#     2020 avg_pkg     11       0
#          stdents     12       0
#     2021 avg_pkg     13       0
#          stdents     14       0
#     2022 avg_pkg     15       0
#          stdents     16       0

# %%
#working with multiindex dataframe
#-------- HEAD AND TAIL --------------
b_df3.head()
# Out:
#            dehli          lahore
#          avg_pkg stdents avg_pkg stdents
# cse 2019       1       2       0       0
#     2020       3       4       0       0
#     2021       5       6       0       0
#     2022       7       8       0       0
# ece 2019       9      10       0       0

# %%
b_df3.unstack().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, cse to ece
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   (dehli, avg_pkg, 2019)   2 non-null      int64
#  1   (dehli, avg_pkg, 2020)   2 non-null      int64
#  2   (dehli, avg_pkg, 2021)   2 non-null      int64
#  3   (dehli, avg_pkg, 2022)   2 non-null      int64
#  4   (dehli, stdents, 2019)   2 non-null      int64
#  5   (dehli, stdents, 2020)   2 non-null      int64
#  6   (dehli, stdents, 2021)   2 non-null      int64
#  7   (dehli, stdents, 2022)   2 non-null      int64
#  8   (lahore, avg_pkg, 2019)  2 non-null      int64
#  9   (lahore, avg_pkg, 2020)  2 non-null      int64
#  10  (lahore, avg_pkg, 2021)  2 non-null      int64
#  11  (lahore, avg_pkg, 2022)  2 non-null      int64
#  12  (lahore, stdents, 2019)  2 non-null      int64
#  13  (lahore, stdents, 2020)  2 non-null      int64
# ...

# %%
b_df3.isnull()
# Out:
#            dehli          lahore
#          avg_pkg stdents avg_pkg stdents
# cse 2019   False   False   False   False
#     2020   False   False   False   False
#     2021   False   False   False   False
#     2022   False   False   False   False
# ece 2019   False   False   False   False
#     2020   False   False   False   False
#     2021   False   False   False   False
#     2022   False   False   False   False

# %%
#-------Extract Single Rows--------------------------------------
b_df3.loc[('cse',2020):('ece',2021):2]
# Out:
#            dehli          lahore
#          avg_pkg stdents avg_pkg stdents
# cse 2020       3       4       0       0
#     2022       7       8       0       0
# ece 2020      11      12       0       0

# %%
b_df3.iloc[1:2]
# Out:
#            dehli          lahore
#          avg_pkg stdents avg_pkg stdents
# cse 2020       3       4       0       0

# %%
#--------------extracting colums----------

b_df3.iloc[:,1:3]
# Out:
#            dehli  lahore
#          stdents avg_pkg
# cse 2019       2       0
#     2020       4       0
#     2021       6       0
#     2022       8       0
# ece 2019      10       0
#     2020      12       0
#     2021      14       0
#     2022      16       0

# %%
# -------------extracting both 
b_df3.iloc[[0,4],[1,2]]
# Out:
#            dehli  lahore
#          stdents avg_pkg
# cse 2019       2       0
# ece 2019      10       0

# %%
#sorting on the basis of index
#-------------------------------------------------------------------
b_df3.sort_index(ascending = False ) #sary data pr sorting krni hai 
b_df3.sort_index(ascending =[False,True]) #phli cols pr krni hai dsre pr nhi krni sorting 
# agr sirf aik level1 pr sorting chahie dsre pr nhi chahie (sirf branch pr sorting krni hai year pr nhi krni)
b_df3.sort_index(level=1 ,ascending =[False]) 
# for level 0 
b_df3.sort_index(level=0 ,ascending =[False])
# Out:
#            dehli          lahore
#          avg_pkg stdents avg_pkg stdents
# ece 2019       9      10       0       0
#     2020      11      12       0       0
#     2021      13      14       0       0
#     2022      15      16       0       0
# cse 2019       1       2       0       0
#     2020       3       4       0       0
#     2021       5       6       0       0
#     2022       7       8       0       0

# %%
#----------transporse----------------
#convert row into column and column into row 
b_df3.transpose()
# Out:
#                 cse                 ece
#                2019 2020 2021 2022 2019 2020 2021 2022
# dehli  avg_pkg    1    3    5    7    9   11   13   15
#        stdents    2    4    6    8   10   12   14   16
# lahore avg_pkg    0    0    0    0    0    0    0    0
#        stdents    0    0    0    0    0    0    0    0

# %%
#----------Swap level------------------
#level 1 (branch) Swap with level 2 (year)

b_df3.swaplevel()
# Out:
#            dehli          lahore
#          avg_pkg stdents avg_pkg stdents
# 2019 cse       1       2       0       0
# 2020 cse       3       4       0       0
# 2021 cse       5       6       0       0
# 2022 cse       7       8       0       0
# 2019 ece       9      10       0       0
# 2020 ece      11      12       0       0
# 2021 ece      13      14       0       0
# 2022 ece      15      16       0       0

# %%
b_df3.swaplevel(axis=1) #colums ko bhi swap kr sakty hain easily
# Out:
#          avg_pkg stdents avg_pkg stdents
#            dehli   dehli  lahore  lahore
# cse 2019       1       2       0       0
#     2020       3       4       0       0
#     2021       5       6       0       0
#     2022       7       8       0       0
# ece 2019       9      10       0       0
#     2020      11      12       0       0
#     2021      13      14       0       0
#     2022      15      16       0       0

# %%
#-----------------long  (tall) vs wide Data-----------------------
 #two functions melt and pivot.

# %%
#__________"melt function": convert wide data into long 
m= pd.DataFrame({'cse':[120]})
m.melt()
# Out:
#   variable  value
# 0      cse    120

# %%
#-----------------another example 

g= pd.DataFrame({'cse':[120],'ece':[200],'math':[80]})
g.melt()
# Out:
#   variable  value
# 0      cse    120
# 1      ece    200
# 2     math     80

# %%
g.melt(var_name='subject',value_name='No. of std')
# Out:
#   subject  No. of std
# 0     cse         120
# 1     ece         200
# 2    math          80

# %%
#____________________REAL WORLD EXAMPLE ____________________

# %%
ts1.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  12/24/22  12/25/22  12/26/22  \
# 0        0        0        0        0  ...    207310    207399    207438
# 1        0        0        0        0  ...    333749    333749    333751
# 2        0        0        0        0  ...    271194    271198    271198
# 3        0        0        0        0  ...     47686     47686     47686
# 4        0        0        0        0  ...    104973    104973    104973
#
#    12/27/22  12/28/22  12/29/22  12/30/22  12/31/22  1/1/23  1/2/23
# ...

# %%
ts2.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  12/24/22  12/25/22  12/26/22  \
# 0        0        0        0        0  ...      7845      7846      7846
# 1        0        0        0        0  ...      3595      3595      3595
# 2        0        0        0        0  ...      6881      6881      6881
# 3        0        0        0        0  ...       165       165       165
# 4        0        0        0        0  ...      1928      1928      1928
#
#    12/27/22  12/28/22  12/29/22  12/30/22  12/31/22  1/1/23  1/2/23
# ...

# %%
Deaths = ts1.melt(id_vars=['Province/State','Country/Region','Lat', 'Long'], var_name='Date',value_name='No. of Deaths')
Deaths.head()
# Out:
#   Province/State Country/Region       Lat       Long     Date  No. of Deaths
# 0            NaN    Afghanistan  33.93911  67.709953  1/22/20              0
# 1            NaN        Albania  41.15330  20.168300  1/22/20              0
# 2            NaN        Algeria  28.03390   1.659600  1/22/20              0
# 3            NaN        Andorra  42.50630   1.521800  1/22/20              0
# 4            NaN         Angola -11.20270  17.873900  1/22/20              0

# %%
confirm = ts2.melt(id_vars=['Province/State','Country/Region','Lat', 'Long'], var_name='Date',value_name='No. of cases')
confirm.head()
# Out:
#   Province/State Country/Region       Lat       Long     Date  No. of cases
# 0            NaN    Afghanistan  33.93911  67.709953  1/22/20             0
# 1            NaN        Albania  41.15330  20.168300  1/22/20             0
# 2            NaN        Algeria  28.03390   1.659600  1/22/20             0
# 3            NaN        Andorra  42.50630   1.521800  1/22/20             0
# 4            NaN         Angola -11.20270  17.873900  1/22/20             0

# %%
#if you want to merge both Data set 
confirm.merge(Deaths,on=['Province/State','Country/Region','Lat', 'Long','Date'])[['Country/Region','Date',	'No. of cases'	,'No. of Deaths']]
# Out:
#               Country/Region     Date  No. of cases  No. of Deaths
# 0                Afghanistan  1/22/20             0              0
# 1                    Albania  1/22/20             0              0
# 2                    Algeria  1/22/20             0              0
# 3                    Andorra  1/22/20             0              0
# 4                     Angola  1/22/20             0              0
# ...                      ...      ...           ...            ...
# 311248    West Bank and Gaza   1/2/23          5708         703228
# 311249  Winter Olympics 2022   1/2/23             0            535
# 311250                 Yemen   1/2/23          2159          11945
# 311251                Zambia   1/2/23          4024         334661
# 311252              Zimbabwe   1/2/23          5637         259981
#
# [311253 rows x 4 columns]

# %% [markdown]
# #----------------------- Pivot Table ---------------------------

# %%
import seaborn as sns #seaborn is used for built-in Dataset that is used in seaborn

# %%
df=sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#pivot table 
df.pivot_table(index='sex',columns='smoker',values='total_bill',aggfunc='count')
# Out:
# C:\Users\me\AppData\Local\Temp\ipykernel_10652\2858439966.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(index='sex',columns='smoker',values='total_bill',aggfunc='count')
# smoker  Yes  No
# sex
# Male     60  97
# Female   33  54

# %%
df.pivot_table(index=['sex','smoker'],columns=['day','time'],values='total_bill')
# Out:
# C:\Users\me\AppData\Local\Temp\ipykernel_10652\4109034156.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(index=['sex','smoker'],columns=['day','time'],values='total_bill')
# day                 Thur               Fri                Sat        Sun
# time               Lunch Dinner      Lunch  Dinner     Dinner     Dinner
# sex    smoker
# Male   Yes     19.171000    NaN  11.386667  25.892  21.837778  26.141333
#        No      18.486500    NaN        NaN  17.475  19.929063  20.403256
# Female Yes     19.218571    NaN  13.260000  12.200  20.266667  16.540000
#        No      15.899167  18.78  15.980000  22.750  19.003846  20.824286

# %%
#-----multidimensional----
df.pivot_table(index=['sex','smoker'],columns=['day','time'],aggfunc={'size':'mean','tip':'max','total_bill':'sum'})
# Out:
# C:\Users\me\AppData\Local\Temp\ipykernel_10652\2569987359.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(index=['sex','smoker'],columns=['day','time'],aggfunc={'size':'mean','tip':'max','total_bill':'sum'})
#                    size                                               tip  \
# day                Thur              Fri              Sat       Sun  Thur
# time              Lunch Dinner     Lunch Dinner    Dinner    Dinner Lunch
# sex    smoker
# Male   Yes     2.300000    NaN  1.666667    2.4  2.629630  2.600000  5.00
#        No      2.500000    NaN       NaN    2.0  2.656250  2.883721  6.70
# Female Yes     2.428571    NaN  2.000000    2.0  2.200000  2.500000  5.00
#        No      2.500000    2.0  3.000000    2.0  2.307692  3.071429  5.17
#
# ...

# %%
#__________margin_____________
df.pivot_table(index='sex',columns='smoker',values='total_bill',aggfunc='count',margins=True)
# Out:
# C:\Users\me\AppData\Local\Temp\ipykernel_10652\4004885340.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(index='sex',columns='smoker',values='total_bill',aggfunc='count',margins=True)
# smoker  Yes   No  All
# sex
# Male     60   97  157
# Female   33   54   87
# All      93  151  244

# %%
#____________plotting graph____________-
exp = pd.read_csv('expense_data.csv')
exp.head()
# Out:
#              Date               Account        Category  Subcategory  \
# 0  3/2/2022 10:11  CUB - online payment            Food          NaN
# 1  3/2/2022 10:11  CUB - online payment           Other          NaN
# 2  3/1/2022 19:50  CUB - online payment            Food          NaN
# 3  3/1/2022 18:56  CUB - online payment  Transportation          NaN
# 4  3/1/2022 18:22  CUB - online payment            Food          NaN
#
#                Note    INR Income/Expense  Note.1  Amount Currency  Account.1
# 0           Brownie   50.0        Expense     NaN    50.0      INR       50.0
# 1  To lended people  300.0        Expense     NaN   300.0      INR      300.0
# 2            Dinner   78.0        Expense     NaN    78.0      INR       78.0
# 3             Metro   30.0        Expense     NaN    30.0      INR       30.0
# 4            Snacks   67.0        Expense     NaN    67.0      INR       67.0

# %%
exp['Date']= pd.to_datetime(exp['Date'])

# %%
exp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            277 non-null    datetime64[ns]
#  1   Account         277 non-null    object
#  2   Category        277 non-null    object
#  3   Subcategory     0 non-null      float64
#  4   Note            273 non-null    object
#  5   INR             277 non-null    float64
#  6   Income/Expense  277 non-null    object
#  7   Note.1          0 non-null      float64
#  8   Amount          277 non-null    float64
#  9   Currency        277 non-null    object
#  10  Account.1       277 non-null    float64
# dtypes: datetime64[ns](1), float64(5), object(5)
# memory usage: 23.9+ KB

# %%
exp['month']= exp['Date'].dt.month_name()

# %%
exp.head()
# Out:
#                  Date               Account        Category  Subcategory  \
# 0 2022-03-02 10:11:00  CUB - online payment            Food          NaN
# 1 2022-03-02 10:11:00  CUB - online payment           Other          NaN
# 2 2022-03-01 19:50:00  CUB - online payment            Food          NaN
# 3 2022-03-01 18:56:00  CUB - online payment  Transportation          NaN
# 4 2022-03-01 18:22:00  CUB - online payment            Food          NaN
#
#                Note    INR Income/Expense  Note.1  Amount Currency  Account.1  \
# 0           Brownie   50.0        Expense     NaN    50.0      INR       50.0
# 1  To lended people  300.0        Expense     NaN   300.0      INR      300.0
# 2            Dinner   78.0        Expense     NaN    78.0      INR       78.0
# 3             Metro   30.0        Expense     NaN    30.0      INR       30.0
# 4            Snacks   67.0        Expense     NaN    67.0      INR       67.0
#
#    month
# 0  March
# 1  March
# 2  March
# 3  March
# ...

# %%
#relationship btw category and month to calculate rupess
exp.pivot_table(index='month',columns='Category',values='INR',aggfunc=sum).plot()
# Out:
# C:\Users\me\AppData\Local\Temp\ipykernel_10652\2007275550.py:2: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   exp.pivot_table(index='month',columns='Category',values='INR',aggfunc=sum).plot()
# <Axes: xlabel='month'>

# %%
exp.pivot_table(index='month',columns='Category',values='INR',aggfunc=sum,fill_value=0 ).plot()
# Out:
# C:\Users\me\AppData\Local\Temp\ipykernel_10652\1863053899.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   exp.pivot_table(index='month',columns='Category',values='INR',aggfunc=sum,fill_value=0 ).plot()
# <Axes: xlabel='month'>

# %%
exp.pivot_table(index='month',columns='Account',values='INR',aggfunc=sum).plot()
# Out:
# C:\Users\me\AppData\Local\Temp\ipykernel_10652\652165664.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   exp.pivot_table(index='month',columns='Account',values='INR',aggfunc=sum).plot()
# <Axes: xlabel='month'>

# %%
#------------- pandas string---------------

# %%
#pandas ko use kr ke string pr koi bhi vectorized operation kr sakty ho

# %%
#vectorized opertaion kya hota hai 
# ----"aik operation ko ap use kr ke sary strings pe apply kr saky ho"----)
a = np.array([1,2,3,4,5])
a + 5
# Out:
# array([ 6,  7,  8,  9, 10])

# %%
#problem in vect in variable in py
w = ['cat','bird','rat',None] #it is slow and can't work with NONE

# %%
# how pandas solved this problem 
s = pd.Series(['cat','bird','rat',None,'copy']) 
#string accessor 
s.str.startswith('c') #--- its ignore the None value and move on
# Out:
# 0     True
# 1    False
# 2    False
# 3     None
# 4     True
# dtype: object

# %%
#import titanic
t = pd.read_csv('titanic.csv')
ts = t['Name']

# %%
ts
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
t.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#-----------common Function---------------------

# %%
#lower/upper/captilized/title
ts.str.lower()
# Out:
# 0                                braund, mr. owen harris
# 1      cumings, mrs. john bradley (florence briggs th...
# 2                                 heikkinen, miss. laina
# 3           futrelle, mrs. jacques heath (lily may peel)
# 4                               allen, mr. william henry
#                              ...
# 886                                montvila, rev. juozas
# 887                         graham, miss. margaret edith
# 888             johnston, miss. catherine helen "carrie"
# 889                                behr, mr. karl howell
# 890                                  dooley, mr. patrick
# Name: Name, Length: 891, dtype: object

# %%
ts.str.upper()
# Out:
# 0                                BRAUND, MR. OWEN HARRIS
# 1      CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 2                                 HEIKKINEN, MISS. LAINA
# 3           FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)
# 4                               ALLEN, MR. WILLIAM HENRY
#                              ...
# 886                                MONTVILA, REV. JUOZAS
# 887                         GRAHAM, MISS. MARGARET EDITH
# 888             JOHNSTON, MISS. CATHERINE HELEN "CARRIE"
# 889                                BEHR, MR. KARL HOWELL
# 890                                  DOOLEY, MR. PATRICK
# Name: Name, Length: 891, dtype: object

# %%
ts.str.capitalize()
# Out:
# 0                                Braund, mr. owen harris
# 1      Cumings, mrs. john bradley (florence briggs th...
# 2                                 Heikkinen, miss. laina
# 3           Futrelle, mrs. jacques heath (lily may peel)
# 4                               Allen, mr. william henry
#                              ...
# 886                                Montvila, rev. juozas
# 887                         Graham, miss. margaret edith
# 888             Johnston, miss. catherine helen "carrie"
# 889                                Behr, mr. karl howell
# 890                                  Dooley, mr. patrick
# Name: Name, Length: 891, dtype: object

# %%
ts.str.title() #---   har word ka phla lfz captial ho jaye ga
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
#len 
ts.str.len()
ts[ts.str.len()== 82].value=[0]#----- jis ka name sab se bra hai

# %%
#strip
'                 maria'.strip() #to remove unneccasry space
# Out:
# 'maria'

# %%
ts.str.strip()
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
#split -> get
t[['title', 'firstname']]= ts.str.split(',').str.get(1).str.strip().str.split(' ',n=1 , expand = True)
t.head()
t['title'].value_counts()
# Out:
# title
# Mr.          517
# Miss.        182
# Mrs.         125
# Master.       40
# Dr.            7
# Rev.           6
# Col.           2
# Mlle.          2
# Major.         2
# Ms.            1
# Mme.           1
# Don.           1
# Lady.          1
# Sir.           1
# Capt.          1
# the            1
# Jonkheer.      1
# Name: count, dtype: int64

# %%
#replace
tsf = t['title'].str.replace('Ms.','Miss.')
tsf = t['title'].str.replace('Mlle.','Miss.')

# %%
tsf.value_counts()
# Out:
# title
# Mr.          517
# Miss.        184
# Mrs.         125
# Master.       40
# Dr.            7
# Rev.           6
# Col.           2
# Major.         2
# Mme.           1
# Don.           1
# Lady.          1
# Ms.            1
# Sir.           1
# Capt.          1
# the            1
# Jonkheer.      1
# Name: count, dtype: int64

# %%
#-----------Filtering--------

# %%
#to check if person name starts with A 
t[t['firstname'].str.endswith('E')]
# Out:
#      PassengerId  Survived  Pclass                      Name     Sex   Age  \
# 30            31         0       1  Uruchurtu, Don. Manuel E    male  40.0
# 412          413         1       1    Minahan, Miss. Daisy E  female  33.0
# 479          480         1       3  Hirvonen, Miss. Hildur E  female   2.0
#
#      SibSp  Parch    Ticket     Fare Cabin Embarked  title firstname
# 30       0      0  PC 17601  27.7208   NaN        C   Don.  Manuel E
# 412      1      0     19928  90.0000   C78        Q  Miss.   Daisy E
# 479      0      1   3101298  12.2875   NaN        S  Miss.  Hildur E

# %%
#is digit / is aplha 
t[t['firstname'].str.isdigit()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, title, firstname]
# Index: []

# %%
#complex and advanced level

# %%
#applying regrex 
#contains 
#jin ke name me jon ata ho

# %%
t[t['firstname'].str.contains('john',case=False)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 41            42         0       2
# 45            46         0       3
# 98            99         1       2
# 112          113         0       3
# 117          118         0       2
# 160          161         0       3
# 162          163         0       3
# 165          166         1       3
# 168          169         0       1
# 188          189         0       3
# 212          213         0       3
# 226          227         1       2
# 227          228         0       3
# 324          325         0       3
# 328          329         1       3
# 401          402         0       3
# 418          419         0       2
# 467          468         0       1
# 527          528         0       1
# 548          549         0       3
# 549          550         1       2
# 550          551         1       1
# 563          564         0       3
# 572          573         1       1
# ...

# %%
#another example

# %%
#find krna hai ke kitny name shuru yan khtm hota hai vowel and char se

t[t['firstname'].str.contains(r'^[AEIOUaeiou].*[AEIOUaeiou]$')]
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 16            17         0       3                   Rice, Master. Eugene
# 38            39         0       3     Vander Planke, Miss. Augusta Maria
# 61            62         1       1                    Icard, Miss. Amelie
# 64            65         0       1                  Stewart, Mr. Albert A
# 68            69         1       3        Andersson, Miss. Erna Alexandra
# 80            81         0       3                   Waelens, Mr. Achille
# 106          107         1       3       Salkjelsvik, Miss. Anna Kristine
# 119          120         0       3      Andersson, Miss. Ellis Anna Maria
# 128          129         1       3                      Peter, Miss. Anna
# 135          136         0       2                     Richard, Mr. Emile
# 141          142         1       3               Nysten, Miss. Anna Sofia
# 152          153         0       3                       Meo, Mr. Alfonzo
# ...

# %%
#---slicing--
t['Name'].str[::-1]
# Out:
# 0                                sirraH newO .rM ,dnuarB
# 1      )reyahT sggirB ecnerolF( yeldarB nhoJ .srM ,sg...
# 2                                 aniaL .ssiM ,nenikkieH
# 3           )leeP yaM yliL( htaeH seuqcaJ .srM ,ellertuF
# 4                               yrneH mailliW .rM ,nellA
#                              ...
# 886                                sazouJ .veR ,alivtnoM
# 887                         htidE teragraM .ssiM ,maharG
# 888             "eirraC" neleH enirehtaC .ssiM ,notsnhoJ
# 889                                llewoH lraK .rM ,rheB
# 890                                  kcirtaP .rM ,yelooD
# Name: Name, Length: 891, dtype: object

# %%
ts.str[:4]
# Out:
# 0                                                        Brau
# 1                                                        Cumi
# 2                                                        Heik
# 3                                                        Futr
# 4                                                        Alle
#                                   ...
# 887                                                      Grah
# 888                                                      John
# 889                                                      Behr
# 890                                                      Dool
# lastname    0       Braund
# 1      Cumings
# 2    Heikkinen
# 3...
# Name: Name, Length: 892, dtype: object

# %%
#-----------date and time in pandas

# %%
# 1- time Stamp object
#--------------------------YEAR MONTH DATE-----------------------------

s = pd.Timestamp('2023/12/9')
s
# Out:
# Timestamp('2023-12-09 00:00:00')

# %%
type(s)
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
pd.Timestamp('2023-12-9') #same syntax
# Out:
# Timestamp('2023-12-09 00:00:00')

# %%
pd.Timestamp('2023,11,9')  #samesyntax
# Out:
# Timestamp('2023-09-01 00:00:00')

# %%
#only year 
pd.Timestamp('2023')
# Out:
# Timestamp('2023-01-01 00:00:00')

# %%
#writting text
s = pd.Timestamp('8 November 2022')
s
# Out:
# Timestamp('2022-11-08 00:00:00')

# %%
#also provide time
s = pd.Timestamp('2023/1/6/9:21:45AM')
s
# Out:
# Timestamp('2023-01-06 09:21:45')

# %%
#PYTHON DATETIME OBJECT 

import datetime as dt
x=pd.Timestamp(dt.datetime(2023,10,3,9,56,33))
x
# Out:
# Timestamp('2023-10-03 09:56:33')

# %%
#fetch attribute

x.year
# Out:
# 2023

# %%
x.month
# Out:
# 10

# %%
x.hour
# Out:
# 9

# %%
x.minute
# Out:
# 56

# %%
x.second
# Out:
# 33

# %%
# quetsion 
#-----is if there is datetime object is exist in python then why pandas introduced built in timestamp function

# %%
#answer 
#---- agr ap py sath work kr rahy to wo slow ho jaye gi big data sath kam krny me

# %%
#__________DATE TIME INDEX____________
pd.DatetimeIndex(['2023/12/4','2022/10/11','2024/2/3'])
# Out:
# DatetimeIndex(['2023-12-04', '2022-10-11', '2024-02-03'], dtype='datetime64[ns]', freq=None)

# %%
pd.DatetimeIndex(['2023/12/4','2022/10/11','2024/2/3'])[0]
# Out:
# Timestamp('2023-12-04 00:00:00')

# %%
#using python datetime object 
h =pd.DatetimeIndex([dt.datetime(2023,10,3),dt.datetime(2029,7,9),dt.datetime(2025,1,30)])
h
# Out:
# DatetimeIndex(['2023-10-03', '2029-07-09', '2025-01-30'], dtype='datetime64[ns]', freq=None)

# %%
#using pd.timestamp
k =pd.DatetimeIndex([pd.Timestamp(2023,10,3),pd.Timestamp(2029,7,9),pd.Timestamp(2025,1,30)])
k
# Out:
# DatetimeIndex(['2023-10-03', '2029-07-09', '2025-01-30'], dtype='datetime64[ns]', freq=None)

# %%
#using datetimeindex as series index

pd.Series([1,2,3],index=k)
# Out:
# 2023-10-03    1
# 2029-07-09    2
# 2025-01-30    3
# dtype: int64

# %%
#___date range____

pd.date_range(start='2023/1/3',end='2023/1/30')
# Out:
# DatetimeIndex(['2023-01-03', '2023-01-04', '2023-01-05', '2023-01-06',
#                '2023-01-07', '2023-01-08', '2023-01-09', '2023-01-10',
#                '2023-01-11', '2023-01-12', '2023-01-13', '2023-01-14',
#                '2023-01-15', '2023-01-16', '2023-01-17', '2023-01-18',
#                '2023-01-19', '2023-01-20', '2023-01-21', '2023-01-22',
#                '2023-01-23', '2023-01-24', '2023-01-25', '2023-01-26',
#                '2023-01-27', '2023-01-28', '2023-01-29', '2023-01-30'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='2023/1/3',end='2023/1/30',freq='D') #for d (synatx me bs frk hai)
# Out:
# DatetimeIndex(['2023-01-03', '2023-01-04', '2023-01-05', '2023-01-06',
#                '2023-01-07', '2023-01-08', '2023-01-09', '2023-01-10',
#                '2023-01-11', '2023-01-12', '2023-01-13', '2023-01-14',
#                '2023-01-15', '2023-01-16', '2023-01-17', '2023-01-18',
#                '2023-01-19', '2023-01-20', '2023-01-21', '2023-01-22',
#                '2023-01-23', '2023-01-24', '2023-01-25', '2023-01-26',
#                '2023-01-27', '2023-01-28', '2023-01-29', '2023-01-30'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='2023/1/3',end='2023/1/30',freq='2D') #for 2d
# Out:
# DatetimeIndex(['2023-01-03', '2023-01-05', '2023-01-07', '2023-01-09',
#                '2023-01-11', '2023-01-13', '2023-01-15', '2023-01-17',
#                '2023-01-19', '2023-01-21', '2023-01-23', '2023-01-25',
#                '2023-01-27', '2023-01-29'],
#               dtype='datetime64[ns]', freq='2D')

# %%
#alternate days in given series
pd.date_range(start='2023/1/3',end='2023/1/30',freq='3D')
# Out:
# DatetimeIndex(['2023-01-03', '2023-01-06', '2023-01-09', '2023-01-12',
#                '2023-01-15', '2023-01-18', '2023-01-21', '2023-01-24',
#                '2023-01-27', '2023-01-30'],
#               dtype='datetime64[ns]', freq='3D')

# %%
#B -> ONLY BUSINESS DAY PRINT krny hai 

pd.date_range(start='2023/1/3',end='2023/1/30',freq='B') #B se mtlb business days
# Out:
# DatetimeIndex(['2023-01-03', '2023-01-04', '2023-01-05', '2023-01-06',
#                '2023-01-09', '2023-01-10', '2023-01-11', '2023-01-12',
#                '2023-01-13', '2023-01-16', '2023-01-17', '2023-01-18',
#                '2023-01-19', '2023-01-20', '2023-01-23', '2023-01-24',
#                '2023-01-25', '2023-01-26', '2023-01-27', '2023-01-30'],
#               dtype='datetime64[ns]', freq='B')

# %%
#W -> ONLY week per DAY PRINT krny hai 

pd.date_range(start='2023/1/3',end='2023/1/30',freq='W') #W se mtlb week per  days
# Out:
# DatetimeIndex(['2023-01-08', '2023-01-15', '2023-01-22', '2023-01-29'], dtype='datetime64[ns]', freq='W-SUN')

# %%
# agar sirf thursday print krny hon to 
pd.date_range(start='2023/1/3',end='2023/1/30',freq='W-THU')
# Out:
# DatetimeIndex(['2023-01-05', '2023-01-12', '2023-01-19', '2023-01-26'], dtype='datetime64[ns]', freq='W-THU')

# %%
# for every hour 
pd.date_range(start='2023/1/3',end='2023/1/30',freq='H')
# Out:
# C:\Users\me\AppData\Local\Temp\ipykernel_10652\1371019281.py:2: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   pd.date_range(start='2023/1/3',end='2023/1/30',freq='H')
# DatetimeIndex(['2023-01-03 00:00:00', '2023-01-03 01:00:00',
#                '2023-01-03 02:00:00', '2023-01-03 03:00:00',
#                '2023-01-03 04:00:00', '2023-01-03 05:00:00',
#                '2023-01-03 06:00:00', '2023-01-03 07:00:00',
#                '2023-01-03 08:00:00', '2023-01-03 09:00:00',
#                ...
#                '2023-01-29 15:00:00', '2023-01-29 16:00:00',
#                '2023-01-29 17:00:00', '2023-01-29 18:00:00',
#                '2023-01-29 19:00:00', '2023-01-29 20:00:00',
#                '2023-01-29 21:00:00', '2023-01-29 22:00:00',
#                '2023-01-29 23:00:00', '2023-01-30 00:00:00'],
#               dtype='datetime64[ns]', length=649, freq='h')

# %%
#for every 6 hours-
pd.date_range(start='2023/1/3',end='2023/1/30',freq='6H')
# Out:
# C:\Users\me\AppData\Local\Temp\ipykernel_10652\3765962241.py:2: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   pd.date_range(start='2023/1/3',end='2023/1/30',freq='6H')
# DatetimeIndex(['2023-01-03 00:00:00', '2023-01-03 06:00:00',
#                '2023-01-03 12:00:00', '2023-01-03 18:00:00',
#                '2023-01-04 00:00:00', '2023-01-04 06:00:00',
#                '2023-01-04 12:00:00', '2023-01-04 18:00:00',
#                '2023-01-05 00:00:00', '2023-01-05 06:00:00',
#                ...
#                '2023-01-27 18:00:00', '2023-01-28 00:00:00',
#                '2023-01-28 06:00:00', '2023-01-28 12:00:00',
#                '2023-01-28 18:00:00', '2023-01-29 00:00:00',
#                '2023-01-29 06:00:00', '2023-01-29 12:00:00',
#                '2023-01-29 18:00:00', '2023-01-30 00:00:00'],
#               dtype='datetime64[ns]', length=109, freq='6h')

# %%
#for year end 
pd.date_range(start='2023/1/3',periods=24,freq='A')
# Out:
# C:\Users\me\AppData\Local\Temp\ipykernel_10652\2082848011.py:2: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   pd.date_range(start='2023/1/3',periods=24,freq='A')
# DatetimeIndex(['2023-12-31', '2024-12-31', '2025-12-31', '2026-12-31',
#                '2027-12-31', '2028-12-31', '2029-12-31', '2030-12-31',
#                '2031-12-31', '2032-12-31', '2033-12-31', '2034-12-31',
#                '2035-12-31', '2036-12-31', '2037-12-31', '2038-12-31',
#                '2039-12-31', '2040-12-31', '2041-12-31', '2042-12-31',
#                '2043-12-31', '2044-12-31', '2045-12-31', '2046-12-31'],
#               dtype='datetime64[ns]', freq='YE-DEC')

# %%
#____to datetime_______

# %%
s= pd.Series(['2023/12/4','2022/10/11','2024/2/3'])
s
# Out:
# 0     2023/12/4
# 1    2022/10/11
# 2      2024/2/3
# dtype: object

# %%
pd.to_datetime(s).dt.day_name()
# Out:
# 0      Monday
# 1     Tuesday
# 2    Saturday
# dtype: object

# %%
pd.to_datetime(s).dt.month_name()
# Out:
# 0    December
# 1     October
# 2    February
# dtype: object

# %%
pd.to_datetime(s).dt.year
# Out:
# 0    2023
# 1    2022
# 2    2024
# dtype: int32

# %%
s= pd.Series(['2023/12/4','2022/10/11','2024/1200/3'])
s
# Out:
# 0      2023/12/4
# 1     2022/10/11
# 2    2024/1200/3
# dtype: object

# %%
#_____With errors 
s.shape
# Out:
# (3,)

# %%
#to solved error 
pd.to_datetime(s,errors= 'coerce')
# Out:
# 0   2023-12-04
# 1   2022-10-11
# 2          NaT
# dtype: datetime64[ns]

# %%
exp.head(2)
# Out:
#                  Date               Account Category  Subcategory  \
# 0 2022-03-02 10:11:00  CUB - online payment     Food          NaN
# 1 2022-03-02 10:11:00  CUB - online payment    Other          NaN
#
#                Note    INR Income/Expense  Note.1  Amount Currency  Account.1  \
# 0           Brownie   50.0        Expense     NaN    50.0      INR       50.0
# 1  To lended people  300.0        Expense     NaN   300.0      INR      300.0
#
#    month
# 0  March
# 1  March

# %%
df = exp

# %%
df
# Out:
#                    Date               Account        Category  Subcategory  \
# 0   2022-03-02 10:11:00  CUB - online payment            Food          NaN
# 1   2022-03-02 10:11:00  CUB - online payment           Other          NaN
# 2   2022-03-01 19:50:00  CUB - online payment            Food          NaN
# 3   2022-03-01 18:56:00  CUB - online payment  Transportation          NaN
# 4   2022-03-01 18:22:00  CUB - online payment            Food          NaN
# ..                  ...                   ...             ...          ...
# 272 2021-11-22 14:16:00  CUB - online payment            Food          NaN
# 273 2021-11-22 14:16:00  CUB - online payment            Food          NaN
# 274 2021-11-21 17:07:00  CUB - online payment  Transportation          NaN
# 275 2021-11-21 15:50:00  CUB - online payment            Food          NaN
# 276 2021-11-21 13:30:00  CUB - online payment           Other          NaN
#
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            277 non-null    datetime64[ns]
#  1   Account         277 non-null    object
#  2   Category        277 non-null    object
#  3   Subcategory     0 non-null      float64
#  4   Note            273 non-null    object
#  5   INR             277 non-null    float64
#  6   Income/Expense  277 non-null    object
#  7   Note.1          0 non-null      float64
#  8   Amount          277 non-null    float64
#  9   Currency        277 non-null    object
#  10  Account.1       277 non-null    float64
#  11  month           277 non-null    object
# dtypes: datetime64[ns](1), float64(5), object(6)
# memory usage: 26.1+ KB

# %%
#____________df accessors

# %%
df['Date'].dt.year
# Out:
# 0      2022
# 1      2022
# 2      2022
# 3      2022
# 4      2022
#        ...
# 272    2021
# 273    2021
# 274    2021
# 275    2021
# 276    2021
# Name: Date, Length: 277, dtype: int32

# %%
df['Date'].dt.month_name()
# Out:
# 0         March
# 1         March
# 2         March
# 3         March
# 4         March
#          ...
# 272    November
# 273    November
# 274    November
# 275    November
# 276    November
# Name: Date, Length: 277, dtype: object

# %%
df['Date'].dt.day
# Out:
# 0       2
# 1       2
# 2       1
# 3       1
# 4       1
#        ..
# 272    22
# 273    22
# 274    21
# 275    21
# 276    21
# Name: Date, Length: 277, dtype: int32

# %%
#----------Plot Graph

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['Date'],df['INR'])
